# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library

# %%
df_can = pd.read_excel(
    'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Canada.xlsx',
    sheet_name='Canada by Citizenship',
    skiprows=range(20),
    skipfooter=2)

# %%
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df_can.tail()
# Out:
#            Type    Coverage          OdName  AREA AreaName  REG  \
# 190  Immigrants  Foreigners        Viet Nam   935     Asia  920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa  912
# 192  Immigrants  Foreigners           Yemen   935     Asia  922
# 193  Immigrants  Foreigners          Zambia   903   Africa  910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa  910
#
#                 RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 190  South-Eastern Asia  902  Developing regions  1191  ...  1816  1852  3153
# 191     Northern Africa  902  Developing regions     0  ...     0     0     1
# 192        Western Asia  902  Developing regions     1  ...   124   161   140
# 193      Eastern Africa  902  Developing regions    11  ...    56    91    77
# 194      Eastern Africa  902  Developing regions    72  ...  1450   615   454
#
#      2007  2008  2009  2010  2011  2012  2013
# 190  2574  1784  2171  1942  1723  1731  2112
# ...

# %%
df_can.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Columns: 43 entries, Type to 2013
# dtypes: int64(37), object(6)
# memory usage: 65.6+ KB

# %%
df_can.columns
# Out:
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013],
#       dtype='object')

# %%
df_can.index=range(0,195)

# %%
print(type(df_can.columns))
print(type(df_can.index))
# Out:
# <class 'pandas.core.indexes.base.Index'>
# <class 'pandas.core.indexes.range.RangeIndex'>

# %%
#df_can.columns.tolist()
#df_can.index.tolist()
#df_can.shape
df_can.drop(['AREA','REG','DEV','Type','Coverage'], axis=1, inplace=True)
df_can.head(2)
# Out:
#         OdName AreaName          RegName             DevName  1980  1981  \
# 0  Afghanistan     Asia    Southern Asia  Developing regions    16    39
# 1      Albania   Europe  Southern Europe   Developed regions     1     0
#
#    1982  1983  1984  1985  ...  2004  2005  2006  2007  2008  2009  2010  \
# 0    39    47    71   340  ...  2978  3436  3009  2652  2111  1746  1758
# 1     0     0     0     0  ...  1450  1223   856   702   560   716   561
#
#    2011  2012  2013
# 0  2203  2635  2004
# 1   539   620   603
#
# [2 rows x 38 columns]

# %%
df_can.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace=True)
df_can.columns
# Out:
# Index([  'Country', 'Continent',    'Region',   'DevName',        1980,
#               1981,        1982,        1983,        1984,        1985,
#               1986,        1987,        1988,        1989,        1990,
#               1991,        1992,        1993,        1994,        1995,
#               1996,        1997,        1998,        1999,        2000,
#               2001,        2002,        2003,        2004,        2005,
#               2006,        2007,        2008,        2009,        2010,
#               2011,        2012,        2013],
#       dtype='object')

# %%
df_can['Total'] = df_can.sum(axis=1,numeric_only=True)
df_can['Total']
# Out:
# Country
# United Kingdom of Great Britain and Northern Ireland    1103000
# United States of America                                 482244
# India                                                   1383808
# Philippines                                             1022782
# China                                                   1319924
#                                                          ...
# Slovenia                                                   1046
# Mongolia                                                   1904
# Monaco                                                       58
# Gambia                                                     1206
# Russian Federation                                       126688
# Name: Total, Length: 195, dtype: int64

# %%
df_can.isnull().sum()
# Out:
# Country      0
# Continent    0
# Region       0
# DevName      0
# 1980         0
# 1981         0
# 1982         0
# 1983         0
# 1984         0
# 1985         0
# 1986         0
# 1987         0
# 1988         0
# 1989         0
# 1990         0
# 1991         0
# 1992         0
# 1993         0
# 1994         0
# 1995         0
# 1996         0
# 1997         0
# 1998         0
# 1999         0
# 2000         0
# 2001         0
# 2002         0
# 2003         0
# 2004         0
# 2005         0
# 2006         0
# 2007         0
# 2008         0
# 2009         0
# 2010         0
# 2011         0
# 2012         0
# 2013         0
# Total        0
# dtype: int64

# %%
df_can.describe()
# Out:
#                1980          1981          1982          1983          1984  \
# count    195.000000    195.000000    195.000000    195.000000    195.000000
# mean     508.394872    566.989744    534.723077    387.435897    376.497436
# std     1949.588546   2152.643752   1866.997511   1204.333597   1198.246371
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%       13.000000     10.000000     11.000000     12.000000     13.000000
# 75%      251.500000    295.500000    275.000000    173.000000    181.000000
# max    22045.000000  24796.000000  20620.000000  10015.000000  10170.000000
#
#               1985         1986          1987          1988          1989  \
# count   195.000000   195.000000    195.000000    195.000000    195.000000
# mean    358.861538   441.271795    691.133333    714.389744    843.241026
# ...

# %%
#df_can.Country
df_can[['Country', 1980,1981, 1982, 1983, 1984, 1985]]
# Out:
#             Country  1980  1981  1982  1983  1984  1985
# 0       Afghanistan    16    39    39    47    71   340
# 1           Albania     1     0     0     0     0     0
# 2           Algeria    80    67    71    69    63    44
# 3    American Samoa     0     1     0     0     0     0
# 4           Andorra     0     0     0     0     0     0
# ..              ...   ...   ...   ...   ...   ...   ...
# 190        Viet Nam  1191  1829  2162  3404  7583  5907
# 191  Western Sahara     0     0     0     0     0     0
# 192           Yemen     1     2     1     6     0    18
# 193          Zambia    11    17    11     7    16     9
# 194        Zimbabwe    72   114   102    44    32    29
#
# [195 rows x 7 columns]

# %%
df_can.set_index('Country', inplace=True)

# %%
#df_can.loc['Afghanistan']

# %%
#df_can.index.name = None
df_can.index.name = 'Country'

# %%
#df_can.index.name

# %%
#df_can.loc['Japan']

# %%
# df_can.reset_index(inplace=True

# df_can.head()

# %%
# df_can.iloc[87]
# df_can[df_can.index == 'Japan']
# df_can.loc['Japan', 2013]
# df_can.iloc[87, 36]
# df_can.loc['Japan', [1980, 1981, 1982, 1983, 1984, 1984]]
#df_can.iloc[87, [3, 4, 5, 6, 7, 8]]
#  df_can.loc['Haiti', map(int,range(1990,1996))]
# df_can.loc['Haiti', range(1990,1996)]


'''
year= list(map(str, range(1990,2014)))
df_can.columns=list(map(str, (x for x in df_can.columns) ))
df_can.loc['Haiti', year]


'''


# numeric_columns = [x for x in df_can.columns if x.isdigit()]
# numeric_columns2 = [x for x in df_can.columns if x.isdigit()==False]
# Convert the filtered column labels to integers
numeric_columns = list(map(int, numeric_columns))

numeric_columns3= numeric_columns2+numeric_columns
year= numeric_columns #list(map(int, range(1990,2014)))

print(numeric_columns3)
df_can.columns=list((x for x in numeric_columns3) )
df_can.loc['Haiti', [numeric_columns]]
# Out:
# ['Continent', 'Region', 'DevName', 'Total', 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[150], line 30
#      28 print(numeric_columns3)
#      29 df_can.columns=list((x for x in numeric_columns3) )
# ---> 30 df_can.loc['Haiti', [numeric_columns]]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# ...

# %%
df_can.head()
# Out:
#                Continent           Region             DevName  1980  1981  \
# Country
# Afghanistan         Asia    Southern Asia  Developing regions    16    39
# Albania           Europe  Southern Europe   Developed regions     1     0
# Algeria           Africa  Northern Africa  Developing regions    80    67
# American Samoa   Oceania        Polynesia  Developing regions     0     1
# Andorra           Europe  Southern Europe   Developed regions     0     0
#
#                 1982  1983  1984  1985  1986  ...  2005  2006  2007  2008  \
# Country                                       ...
# Afghanistan       39    47    71   340   496  ...  3436  3009  2652  2111
# Albania            0     0     0     0     1  ...  1223   856   702   560
# Algeria           71    69    63    44    69  ...  3626  4807  3623  4005
# American Samoa     0     0     0     0     0  ...     0     1     0     0
# Andorra            0     0     0     0     2  ...     0     1     1     0
#
# ...

# %%
# a=df_can['Continent']=='Asia'
# true_values = a[a.values]
# print(true_values)

# %%
# df_can[(df_can['Continent']=='Asia') & (df_can['Region']=='Southern Asia')]

# %%
df_can[(df_can['Continent']=='Africa') & (df_can['Region']=='Southern Africa')]
# Out:
#              Continent           Region             DevName  Total  1980  \
# Country
# Botswana        Africa  Southern Africa  Developing regions     10     1
# Lesotho         Africa  Southern Africa  Developing regions      1     1
# Namibia         Africa  Southern Africa  Developing regions      0     5
# South Africa    Africa  Southern Africa  Developing regions   1026  1118
# Swaziland       Africa  Southern Africa  Developing regions      4     1
#
#               1981  1982  1983  1984  1985  ...  2004  2005  2006  2007  2008  \
# Country                                     ...
# Botswana         3     3     7     4     2  ...     7    11     8    28    15
# Lesotho          1     2     7     5     3  ...     4     0     4     1     8
# Namibia          5     3     2     1     1  ...     6    19    13    26    14
# South Africa   781   379   271   310   718  ...   988  1111  1200  1123  1188
# Swaziland        1     0    10     7     1  ...     7     7     5     6    10
#
# ...

# %%
df_can.head()
# Out:
#                Continent           Region             DevName  Total  1980  \
# Country
# Afghanistan         Asia    Southern Asia  Developing regions     16    39
# Albania           Europe  Southern Europe   Developed regions      1     0
# Algeria           Africa  Northern Africa  Developing regions     80    67
# American Samoa   Oceania        Polynesia  Developing regions      0     1
# Andorra           Europe  Southern Europe   Developed regions      0     0
#
#                 1981  1982  1983  1984  1985  ...  2004  2005  2006  2007  \
# Country                                       ...
# Afghanistan       39    47    71   340   496  ...  3436  3009  2652  2111
# Albania            0     0     0     0     1  ...  1223   856   702   560
# Algeria           71    69    63    44    69  ...  3626  4807  3623  4005
# American Samoa     0     0     0     0     0  ...     0     1     0     0
# Andorra            0     0     0     0     2  ...     0     1     1     0
#
# ...

# %%
df_can.sort_values(by='Total', ascending=False , axis=0, inplace=True)
df_can.head(5)
# Out:
#                                                    Continent  \
# Country
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
#
#                                                                 Region  \
# Country
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# Philippines                                         South-Eastern Asia
# Pakistan                                                 Southern Asia
#
#                                                                DevName  \
# Country
# ...

# %%
df_can.sort_values(by=2010, ascending=False , axis=0, inplace=True)
df_can[[2010]].head(5)
# Out:
#                              2010
# Country
# Philippines                 36765
# China                       28502
# India                       27509
# United States of America     7676
# Iran (Islamic Republic of)   7479

# %%
# Out:
# Index(['India', 'China',
#        'United Kingdom of Great Britain and Northern Ireland', 'Philippines',
#        'Pakistan', 'United States of America', 'Iran (Islamic Republic of)',
#        'Sri Lanka', 'Republic of Korea', 'Poland',
#        ...
#        'Kiribati', 'Vanuatu', 'Sao Tome and Principe', 'Tuvalu',
#        'American Samoa', 'New Caledonia', 'San Marino', 'Marshall Islands',
#        'Western Sahara', 'Palau'],
#       dtype='object', name='Country', length=195)
