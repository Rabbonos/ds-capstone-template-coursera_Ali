# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Space X  Falcon 9 First Stage Landing Prediction**

# %% [markdown]
# ## Web scraping Falcon 9 and Falcon Heavy Launches Records from Wikipedia

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# In this lab, you will be performing web scraping to collect Falcon 9 historical launch records from a Wikipedia page titled `List of Falcon 9 and Falcon Heavy launches`
#
# https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_1_L2/images/Falcon9_rocket_family.svg)

# %% [markdown]
# Falcon 9 first stage will land successfully

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/landing_1.gif)

# %% [markdown]
# Several examples of an unsuccessful landing are shown here:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/crash.gif)

# %% [markdown]
# More specifically, the launch records are stored in a HTML table shown below:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_1_L2/images/falcon9-launches-wiki.png)

# %% [markdown]
#   ## Objectives
# Web scrap Falcon 9 launch records with `BeautifulSoup`:
# - Extract a Falcon 9 launch records HTML table from Wikipedia
# - Parse the table and convert it into a Pandas data frame

# %% [markdown]
# First let's import required packages for this lab

# %%
# !pip3 install beautifulsoup4
# !pip3 install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from beautifulsoup4) (2.3.2.post1)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (2023.5.7)

# %%
import sys

import requests
from bs4 import BeautifulSoup
import re
import unicodedata
import pandas as pd

# %% [markdown]
# and we will provide some helper functions for you to process web scraped HTML table

# %%
def date_time(table_cells):
    """
    This function returns the data and time from the HTML  table cell
    Input: the  element of a table data cell extracts extra row
    """
    return [data_time.strip() for data_time in list(table_cells.strings)][0:2]

def booster_version(table_cells):
    """
    This function returns the booster version from the HTML  table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=''.join([booster_version for i,booster_version in enumerate( table_cells.strings) if i%2==0][0:-1])
    return out

def landing_status(table_cells):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=[i for i in table_cells.strings][0]
    return out


def get_mass(table_cells):
    mass=unicodedata.normalize("NFKD", table_cells.text).strip()
    if mass:
        mass.find("kg")
        new_mass=mass[0:mass.find("kg")+2]
    else:
        new_mass=0
    return new_mass


def extract_column_from_header(row):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    if (row.br):
        row.br.extract()
    if row.a:
        row.a.extract()
    if row.sup:
        row.sup.extract()
        
    colunm_name = ' '.join(row.contents)
    
    # Filter the digit and empty names
    if not(colunm_name.strip().isdigit()):
        colunm_name = colunm_name.strip()
        return colunm_name

# %% [markdown]
# To keep the lab tasks consistent, you will be asked to scrape the data from a snapshot of the  `List of Falcon 9 and Falcon Heavy launches` Wikipage updated on
# `9th June 2021`

# %%
static_url = "https://en.wikipedia.org/w/index.php?title=List_of_Falcon_9_and_Falcon_Heavy_launches&oldid=1027686922"

# %% [markdown]
# Next, request the HTML page from the above URL and get a `response` object

# %% [markdown]
# ### TASK 1: Request the Falcon9 Launch Wiki page from its URL

# %% [markdown]
# First, let's perform an HTTP GET method to request the Falcon9 Launch HTML page, as an HTTP response.

# %%
# use requests.get() method with the provided static_url
# assign the response to a object
url=r'https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches_(2020%E2%80%932022)'

#content=requests.get(url).content

# %%
content= BeautifulSoup(content) 


headers=content.find("tbody")
headers=content.find("tr", class_='is-sticky')
headers=headers.find_all('th')
header_text = [header.text.strip() for header in headers]
header_text
# Out:
# ['Flight No.',
#  'Date andtime (UTC)',
#  'Version,booster[a]',
#  'Launchsite',
#  'Payload[b]',
#  'Payload mass',
#  'Orbit',
#  'Customer',
#  'Launchoutcome',
#  'Boosterlanding']

# %%
df=pd.DataFrame(columns= header_text)
df.columns
# Out:
# Index(['Flight No.', 'Date andtime (UTC)', 'Version,booster[a]', 'Launchsite',
#        'Payload[b]', 'Payload mass', 'Orbit', 'Customer', 'Launchoutcome',
#        'Boosterlanding'],
#       dtype='object')

# %% [markdown]
# Create a `BeautifulSoup` object from the HTML `response`

# %%
# Use BeautifulSoup() to create a BeautifulSoup object from a response text content

# %% [markdown]
# Print the page title to verify if the `BeautifulSoup` object was created properly

# %%
# Use soup.title attribute
content.title
# Out:
# <title>List of Falcon 9 and Falcon Heavy launches (2020–2022) - Wikipedia</title>

# %% [markdown]
# ### TASK 2: Extract all column/variable names from the HTML table header

# %% [markdown]
# Next, we want to collect all relevant column names from the HTML table header

# %% [markdown]
# Let's try to find all tables on the wiki page first. If you need to refresh your memory about `BeautifulSoup`, please check the external reference link towards the end of this lab

# %%
df
# Out:
#                   Flight No.         Date andtime (UTC)   Version,booster[a]  \
# 0                         78  7 January 202002:19:21[3]      F9 B5 ♺ B1049.4
# 1                         79    19 January 202015:30[6]      F9 B5 ♺ B1046.4
# 2                         80   29 January 202014:07[14]      F9 B5 ♺ B1051.3
# 3                         81  17 February 202015:05[16]      F9 B5 ♺ B1056.4
# 4                         82      7 March 202004:50[19]      F9 B5 ♺ B1059.2
# ..                       ...                        ...                  ...
# 114  ispace MBRSC  JAXA NASA                    Success  Success(ground pad)
# 115                NASA/CNES                    Success  Success(ground pad)
# 116                      SES                    Success  Success(drone ship)
# 117                   SpaceX                    Success  Success(drone ship)
# 118                   SpaceX                    Success  Success(drone ship)
#
#        Launchsite                                         Payload[b]  \
# 0    CCSFS,SLC-40                    Starlink 2 v1.0 (60 satellites)
# 1      KSC,LC-39A  Crew Dragon in-flight abort test[7](Dragon C20...
# 2    CCSFS,SLC-40                    Starlink 3 v1.0 (60 satellites)
# 3    CCSFS,SLC-40                    Starlink 4 v1.0 (60 satellites)
# 4    CCSFS,SLC-40                    SpaceX CRS-20(Dragon C112.3 ♺ )
# ..            ...                                                ...
# 114           190                         16 December 202211:46[433]
# 115           191                         16 December 202222:48[437]
# 116           192                         17 December 202221:32[437]
# 117           193                         28 December 202209:34[441]
# 118           194                         30 December 202207:38[444]
#
#                                     Payload mass           Orbit  \
# 0                       15,600 kg (34,400 lb)[4]             LEO
# 1                          12,050 kg (26,570 lb)  Sub-orbital[8]
# 2                       15,600 kg (34,400 lb)[4]             LEO
# 3                       15,600 kg (34,400 lb)[4]             LEO
# 4    1,977 kg (4,359 lb)[20] (excl. Dragon mass)       LEO (ISS)
# ..                                           ...             ...
# 114                              F9 B5 ♺ B1071.6     VSFB,SLC-4E
# 115                              F9 B5 ♺ B1067.8    CCSFS,SLC-40
# 116                             F9 B5 ♺ B1058.15      KSC,LC-39A
# 117                             F9 B5 ♺ B1062.11    CCSFS,SLC-40
# 118                             F9 B5 ♺ B1061.11     VSFB,SLC-4E
#
#                                            Customer  \
# 0                                            SpaceX
# 1                                     NASA (CTS)[9]
# 2                                            SpaceX
# 3                                            SpaceX
# 4                                        NASA (CRS)
# ..                                              ...
# 114  Surface Water and Ocean Topography (SWOT)[434]
# 115                                O3b mPOWER 1 & 2
# 116        Starlink Group 4-37[440] (54 satellites)
# 117              Starlink Group 5-1 (54 satellites)
# 118                                    EROS-C3[445]
#
#                  Launchoutcome       Boosterlanding
# 0                      Success  Success(drone ship)
# 1                      Success           No attempt
# 2                      Success  Success(drone ship)
# 3                      Success  Failure(drone ship)
# 4                      Success  Success(ground pad)
# ..                         ...                  ...
# 114  ~2,200 kg (4,900 lb)[435]                  LEO
# 115       ~4,100 kg (9,000 lb)                  MEO
# 116     ~16,700 kg (36,800 lb)                  LEO
# 117     ~16,700 kg (36,800 lb)                  LEO
# 118           ~400 kg (880 lb)       Retrograde LEO
#
# [119 rows x 10 columns]

# %%
# Use the find_all function in the BeautifulSoup object, with element type `table`
# Assign the result to a list called `html_tables`


tables = content.select('tbody:nth-of-type(-n+3)') 
#tables=content.select('tbody')
#print(rows)
#rows=rows.find_all('td')

columns=df.columns


for table in tables:
    cells = table.select('th[rowspan], td:not([colspan])') # selects all td without class 
    
    j=0 
    row_real={}
    
    for cell in cells:
        flag=True 
        #print('--------------------------------------------------------')

        row_real[columns[j]]=cell.text.strip()
        print(row_real , 'realniy ryad')
        


        row_real[columns[j]]=cell.text.strip()


        if j==9:
            print('RESHAYUSHIY ',cell.text.strip())
            df=df.append(row_real,ignore_index=True)
            j=0
            row_real={}
            flag=False
            
        if flag == True:    
            j+=1    
            
                
    #i+=1
#df.iloc[i][j]=rowdata.text
#df = df.dropna(how='all')
# Out:
# {'Flight No.': '78'} realniy ryad
# {'Flight No.': '78', 'Date andtime (UTC)': '7 January 202002:19:21[3]'} realniy ryad
# {'Flight No.': '78', 'Date andtime (UTC)': '7 January 202002:19:21[3]', 'Version,booster[a]': 'F9 B5 ♺ B1049.4'} realniy ryad
# {'Flight No.': '78', 'Date andtime (UTC)': '7 January 202002:19:21[3]', 'Version,booster[a]': 'F9 B5 ♺ B1049.4', 'Launchsite': 'CCSFS,SLC-40'} realniy ryad
# {'Flight No.': '78', 'Date andtime (UTC)': '7 January 202002:19:21[3]', 'Version,booster[a]': 'F9 B5 ♺ B1049.4', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 2 v1.0 (60\xa0satellites)'} realniy ryad
# {'Flight No.': '78', 'Date andtime (UTC)': '7 January 202002:19:21[3]', 'Version,booster[a]': 'F9 B5 ♺ B1049.4', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 2 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]'} realniy ryad
# {'Flight No.': '78', 'Date andtime (UTC)': '7 January 202002:19:21[3]', 'Version,booster[a]': 'F9 B5 ♺ B1049.4', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 2 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO'} realniy ryad
# {'Flight No.': '78', 'Date andtime (UTC)': '7 January 202002:19:21[3]', 'Version,booster[a]': 'F9 B5 ♺ B1049.4', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 2 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX'} realniy ryad
# {'Flight No.': '78', 'Date andtime (UTC)': '7 January 202002:19:21[3]', 'Version,booster[a]': 'F9 B5 ♺ B1049.4', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 2 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '78', 'Date andtime (UTC)': '7 January 202002:19:21[3]', 'Version,booster[a]': 'F9 B5 ♺ B1049.4', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 2 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launchoutcome': 'Success', 'Boosterlanding': 'Success(drone ship)'} realniy ryad
# RESHAYUSHIY  Success(drone ship)
# {'Flight No.': '79'} realniy ryad
# {'Flight No.': '79', 'Date andtime (UTC)': '19 January 202015:30[6]'} realniy ryad
# {'Flight No.': '79', 'Date andtime (UTC)': '19 January 202015:30[6]', 'Version,booster[a]': 'F9 B5 ♺ B1046.4'} realniy ryad
# {'Flight No.': '79', 'Date andtime (UTC)': '19 January 202015:30[6]', 'Version,booster[a]': 'F9 B5 ♺ B1046.4', 'Launchsite': 'KSC,LC-39A'} realniy ryad
# {'Flight No.': '79', 'Date andtime (UTC)': '19 January 202015:30[6]', 'Version,booster[a]': 'F9 B5 ♺ B1046.4', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Crew Dragon in-flight abort test[7](Dragon C205.1)'} realniy ryad
# {'Flight No.': '79', 'Date andtime (UTC)': '19 January 202015:30[6]', 'Version,booster[a]': 'F9 B5 ♺ B1046.4', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Crew Dragon in-flight abort test[7](Dragon C205.1)', 'Payload mass': '12,050\xa0kg (26,570\xa0lb)'} realniy ryad
# {'Flight No.': '79', 'Date andtime (UTC)': '19 January 202015:30[6]', 'Version,booster[a]': 'F9 B5 ♺ B1046.4', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Crew Dragon in-flight abort test[7](Dragon C205.1)', 'Payload mass': '12,050\xa0kg (26,570\xa0lb)', 'Orbit': 'Sub-orbital[8]'} realniy ryad
# {'Flight No.': '79', 'Date andtime (UTC)': '19 January 202015:30[6]', 'Version,booster[a]': 'F9 B5 ♺ B1046.4', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Crew Dragon in-flight abort test[7](Dragon C205.1)', 'Payload mass': '12,050\xa0kg (26,570\xa0lb)', 'Orbit': 'Sub-orbital[8]', 'Customer': 'NASA (CTS)[9]'} realniy ryad
# {'Flight No.': '79', 'Date andtime (UTC)': '19 January 202015:30[6]', 'Version,booster[a]': 'F9 B5 ♺ B1046.4', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Crew Dragon in-flight abort test[7](Dragon C205.1)', 'Payload mass': '12,050\xa0kg (26,570\xa0lb)', 'Orbit': 'Sub-orbital[8]', 'Customer': 'NASA (CTS)[9]', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '79', 'Date andtime (UTC)': '19 January 202015:30[6]', 'Version,booster[a]': 'F9 B5 ♺ B1046.4', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Crew Dragon in-flight abort test[7](Dragon C205.1)', 'Payload mass': '12,050\xa0kg (26,570\xa0lb)', 'Orbit': 'Sub-orbital[8]', 'Customer': 'NASA (CTS)[9]', 'Launchoutcome': 'Success', 'Boosterlanding': 'No attempt'} realniy ryad
# RESHAYUSHIY  No attempt
# {'Flight No.': '80'} realniy ryad
# {'Flight No.': '80', 'Date andtime (UTC)': '29 January 202014:07[14]'} realniy ryad
# {'Flight No.': '80', 'Date andtime (UTC)': '29 January 202014:07[14]', 'Version,booster[a]': 'F9 B5 ♺ B1051.3'} realniy ryad
# {'Flight No.': '80', 'Date andtime (UTC)': '29 January 202014:07[14]', 'Version,booster[a]': 'F9 B5 ♺ B1051.3', 'Launchsite': 'CCSFS,SLC-40'} realniy ryad
# {'Flight No.': '80', 'Date andtime (UTC)': '29 January 202014:07[14]', 'Version,booster[a]': 'F9 B5 ♺ B1051.3', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 3 v1.0 (60\xa0satellites)'} realniy ryad
# {'Flight No.': '80', 'Date andtime (UTC)': '29 January 202014:07[14]', 'Version,booster[a]': 'F9 B5 ♺ B1051.3', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 3 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]'} realniy ryad
# {'Flight No.': '80', 'Date andtime (UTC)': '29 January 202014:07[14]', 'Version,booster[a]': 'F9 B5 ♺ B1051.3', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 3 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO'} realniy ryad
# {'Flight No.': '80', 'Date andtime (UTC)': '29 January 202014:07[14]', 'Version,booster[a]': 'F9 B5 ♺ B1051.3', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 3 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX'} realniy ryad
# {'Flight No.': '80', 'Date andtime (UTC)': '29 January 202014:07[14]', 'Version,booster[a]': 'F9 B5 ♺ B1051.3', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 3 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '80', 'Date andtime (UTC)': '29 January 202014:07[14]', 'Version,booster[a]': 'F9 B5 ♺ B1051.3', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 3 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launchoutcome': 'Success', 'Boosterlanding': 'Success(drone ship)'} realniy ryad
# RESHAYUSHIY  Success(drone ship)
# {'Flight No.': '81'} realniy ryad
# {'Flight No.': '81', 'Date andtime (UTC)': '17 February 202015:05[16]'} realniy ryad
# {'Flight No.': '81', 'Date andtime (UTC)': '17 February 202015:05[16]', 'Version,booster[a]': 'F9 B5 ♺ B1056.4'} realniy ryad
# {'Flight No.': '81', 'Date andtime (UTC)': '17 February 202015:05[16]', 'Version,booster[a]': 'F9 B5 ♺ B1056.4', 'Launchsite': 'CCSFS,SLC-40'} realniy ryad
# {'Flight No.': '81', 'Date andtime (UTC)': '17 February 202015:05[16]', 'Version,booster[a]': 'F9 B5 ♺ B1056.4', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 4 v1.0 (60\xa0satellites)'} realniy ryad
# {'Flight No.': '81', 'Date andtime (UTC)': '17 February 202015:05[16]', 'Version,booster[a]': 'F9 B5 ♺ B1056.4', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 4 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]'} realniy ryad
# {'Flight No.': '81', 'Date andtime (UTC)': '17 February 202015:05[16]', 'Version,booster[a]': 'F9 B5 ♺ B1056.4', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 4 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO'} realniy ryad
# {'Flight No.': '81', 'Date andtime (UTC)': '17 February 202015:05[16]', 'Version,booster[a]': 'F9 B5 ♺ B1056.4', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 4 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX'} realniy ryad
# {'Flight No.': '81', 'Date andtime (UTC)': '17 February 202015:05[16]', 'Version,booster[a]': 'F9 B5 ♺ B1056.4', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 4 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '81', 'Date andtime (UTC)': '17 February 202015:05[16]', 'Version,booster[a]': 'F9 B5 ♺ B1056.4', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 4 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launchoutcome': 'Success', 'Boosterlanding': 'Failure(drone ship)'} realniy ryad
# RESHAYUSHIY  Failure(drone ship)
# {'Flight No.': '82'} realniy ryad
# {'Flight No.': '82', 'Date andtime (UTC)': '7 March 202004:50[19]'} realniy ryad
# {'Flight No.': '82', 'Date andtime (UTC)': '7 March 202004:50[19]', 'Version,booster[a]': 'F9 B5 ♺ B1059.2'} realniy ryad
# {'Flight No.': '82', 'Date andtime (UTC)': '7 March 202004:50[19]', 'Version,booster[a]': 'F9 B5 ♺ B1059.2', 'Launchsite': 'CCSFS,SLC-40'} realniy ryad
# {'Flight No.': '82', 'Date andtime (UTC)': '7 March 202004:50[19]', 'Version,booster[a]': 'F9 B5 ♺ B1059.2', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'SpaceX CRS-20(Dragon C112.3 ♺ )'} realniy ryad
# {'Flight No.': '82', 'Date andtime (UTC)': '7 March 202004:50[19]', 'Version,booster[a]': 'F9 B5 ♺ B1059.2', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'SpaceX CRS-20(Dragon C112.3 ♺ )', 'Payload mass': '1,977\xa0kg (4,359\xa0lb)[20] (excl. Dragon mass)'} realniy ryad
# {'Flight No.': '82', 'Date andtime (UTC)': '7 March 202004:50[19]', 'Version,booster[a]': 'F9 B5 ♺ B1059.2', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'SpaceX CRS-20(Dragon C112.3 ♺ )', 'Payload mass': '1,977\xa0kg (4,359\xa0lb)[20] (excl. Dragon mass)', 'Orbit': 'LEO (ISS)'} realniy ryad
# {'Flight No.': '82', 'Date andtime (UTC)': '7 March 202004:50[19]', 'Version,booster[a]': 'F9 B5 ♺ B1059.2', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'SpaceX CRS-20(Dragon C112.3 ♺ )', 'Payload mass': '1,977\xa0kg (4,359\xa0lb)[20] (excl. Dragon mass)', 'Orbit': 'LEO (ISS)', 'Customer': 'NASA (CRS)'} realniy ryad
# {'Flight No.': '82', 'Date andtime (UTC)': '7 March 202004:50[19]', 'Version,booster[a]': 'F9 B5 ♺ B1059.2', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'SpaceX CRS-20(Dragon C112.3 ♺ )', 'Payload mass': '1,977\xa0kg (4,359\xa0lb)[20] (excl. Dragon mass)', 'Orbit': 'LEO (ISS)', 'Customer': 'NASA (CRS)', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '82', 'Date andtime (UTC)': '7 March 202004:50[19]', 'Version,booster[a]': 'F9 B5 ♺ B1059.2', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'SpaceX CRS-20(Dragon C112.3 ♺ )', 'Payload mass': '1,977\xa0kg (4,359\xa0lb)[20] (excl. Dragon mass)', 'Orbit': 'LEO (ISS)', 'Customer': 'NASA (CRS)', 'Launchoutcome': 'Success', 'Boosterlanding': 'Success(ground pad)'} realniy ryad
# RESHAYUSHIY  Success(ground pad)
# {'Flight No.': '83'} realniy ryad
# {'Flight No.': '83', 'Date andtime (UTC)': '18 March 202012:16[23]'} realniy ryad
# {'Flight No.': '83', 'Date andtime (UTC)': '18 March 202012:16[23]', 'Version,booster[a]': 'F9 B5 ♺ B1048.5'} realniy ryad
# {'Flight No.': '83', 'Date andtime (UTC)': '18 March 202012:16[23]', 'Version,booster[a]': 'F9 B5 ♺ B1048.5', 'Launchsite': 'KSC,LC-39A'} realniy ryad
# {'Flight No.': '83', 'Date andtime (UTC)': '18 March 202012:16[23]', 'Version,booster[a]': 'F9 B5 ♺ B1048.5', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 5 v1.0 (60\xa0satellites)'} realniy ryad
# {'Flight No.': '83', 'Date andtime (UTC)': '18 March 202012:16[23]', 'Version,booster[a]': 'F9 B5 ♺ B1048.5', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 5 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]'} realniy ryad
# {'Flight No.': '83', 'Date andtime (UTC)': '18 March 202012:16[23]', 'Version,booster[a]': 'F9 B5 ♺ B1048.5', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 5 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO'} realniy ryad
# {'Flight No.': '83', 'Date andtime (UTC)': '18 March 202012:16[23]', 'Version,booster[a]': 'F9 B5 ♺ B1048.5', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 5 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX'} realniy ryad
# {'Flight No.': '83', 'Date andtime (UTC)': '18 March 202012:16[23]', 'Version,booster[a]': 'F9 B5 ♺ B1048.5', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 5 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '83', 'Date andtime (UTC)': '18 March 202012:16[23]', 'Version,booster[a]': 'F9 B5 ♺ B1048.5', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 5 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launchoutcome': 'Success', 'Boosterlanding': 'Failure(drone ship)'} realniy ryad
# RESHAYUSHIY  Failure(drone ship)
# {'Flight No.': '84'} realniy ryad
# {'Flight No.': '84', 'Date andtime (UTC)': '22 April 202019:30[27]'} realniy ryad
# {'Flight No.': '84', 'Date andtime (UTC)': '22 April 202019:30[27]', 'Version,booster[a]': 'F9 B5 ♺ B1051.4'} realniy ryad
# {'Flight No.': '84', 'Date andtime (UTC)': '22 April 202019:30[27]', 'Version,booster[a]': 'F9 B5 ♺ B1051.4', 'Launchsite': 'KSC,LC-39A'} realniy ryad
# {'Flight No.': '84', 'Date andtime (UTC)': '22 April 202019:30[27]', 'Version,booster[a]': 'F9 B5 ♺ B1051.4', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 6 v1.0 (60\xa0satellites)'} realniy ryad
# {'Flight No.': '84', 'Date andtime (UTC)': '22 April 202019:30[27]', 'Version,booster[a]': 'F9 B5 ♺ B1051.4', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 6 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]'} realniy ryad
# {'Flight No.': '84', 'Date andtime (UTC)': '22 April 202019:30[27]', 'Version,booster[a]': 'F9 B5 ♺ B1051.4', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 6 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO'} realniy ryad
# {'Flight No.': '84', 'Date andtime (UTC)': '22 April 202019:30[27]', 'Version,booster[a]': 'F9 B5 ♺ B1051.4', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 6 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX'} realniy ryad
# {'Flight No.': '84', 'Date andtime (UTC)': '22 April 202019:30[27]', 'Version,booster[a]': 'F9 B5 ♺ B1051.4', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 6 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '84', 'Date andtime (UTC)': '22 April 202019:30[27]', 'Version,booster[a]': 'F9 B5 ♺ B1051.4', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 6 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launchoutcome': 'Success', 'Boosterlanding': 'Success(drone ship)'} realniy ryad
# RESHAYUSHIY  Success(drone ship)
# {'Flight No.': '85'} realniy ryad
# {'Flight No.': '85', 'Date andtime (UTC)': '30 May 202019:22[30]'} realniy ryad
# {'Flight No.': '85', 'Date andtime (UTC)': '30 May 202019:22[30]', 'Version,booster[a]': 'F9 B5 B1058.1[31]'} realniy ryad
# {'Flight No.': '85', 'Date andtime (UTC)': '30 May 202019:22[30]', 'Version,booster[a]': 'F9 B5 B1058.1[31]', 'Launchsite': 'KSC,LC-39A'} realniy ryad
# {'Flight No.': '85', 'Date andtime (UTC)': '30 May 202019:22[30]', 'Version,booster[a]': 'F9 B5 B1058.1[31]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Crew Dragon Demo-2[32](Crew Dragon C206.1 Endeavour)'} realniy ryad
# {'Flight No.': '85', 'Date andtime (UTC)': '30 May 202019:22[30]', 'Version,booster[a]': 'F9 B5 B1058.1[31]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Crew Dragon Demo-2[32](Crew Dragon C206.1 Endeavour)', 'Payload mass': '12,530\xa0kg (27,620\xa0lb)[33]'} realniy ryad
# {'Flight No.': '85', 'Date andtime (UTC)': '30 May 202019:22[30]', 'Version,booster[a]': 'F9 B5 B1058.1[31]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Crew Dragon Demo-2[32](Crew Dragon C206.1 Endeavour)', 'Payload mass': '12,530\xa0kg (27,620\xa0lb)[33]', 'Orbit': 'LEO (ISS)'} realniy ryad
# {'Flight No.': '85', 'Date andtime (UTC)': '30 May 202019:22[30]', 'Version,booster[a]': 'F9 B5 B1058.1[31]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Crew Dragon Demo-2[32](Crew Dragon C206.1 Endeavour)', 'Payload mass': '12,530\xa0kg (27,620\xa0lb)[33]', 'Orbit': 'LEO (ISS)', 'Customer': 'NASA (CCDev)'} realniy ryad
# {'Flight No.': '85', 'Date andtime (UTC)': '30 May 202019:22[30]', 'Version,booster[a]': 'F9 B5 B1058.1[31]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Crew Dragon Demo-2[32](Crew Dragon C206.1 Endeavour)', 'Payload mass': '12,530\xa0kg (27,620\xa0lb)[33]', 'Orbit': 'LEO (ISS)', 'Customer': 'NASA (CCDev)', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '85', 'Date andtime (UTC)': '30 May 202019:22[30]', 'Version,booster[a]': 'F9 B5 B1058.1[31]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Crew Dragon Demo-2[32](Crew Dragon C206.1 Endeavour)', 'Payload mass': '12,530\xa0kg (27,620\xa0lb)[33]', 'Orbit': 'LEO (ISS)', 'Customer': 'NASA (CCDev)', 'Launchoutcome': 'Success', 'Boosterlanding': 'Success(drone ship)'} realniy ryad
# RESHAYUSHIY  Success(drone ship)
# {'Flight No.': '86'} realniy ryad
# {'Flight No.': '86', 'Date andtime (UTC)': '4 June 202001:25[35]'} realniy ryad
# {'Flight No.': '86', 'Date andtime (UTC)': '4 June 202001:25[35]', 'Version,booster[a]': 'F9 B5 ♺ B1049.5'} realniy ryad
# {'Flight No.': '86', 'Date andtime (UTC)': '4 June 202001:25[35]', 'Version,booster[a]': 'F9 B5 ♺ B1049.5', 'Launchsite': 'CCSFS,SLC-40'} realniy ryad
# {'Flight No.': '86', 'Date andtime (UTC)': '4 June 202001:25[35]', 'Version,booster[a]': 'F9 B5 ♺ B1049.5', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 7 v1.0 (60\xa0satellites)'} realniy ryad
# {'Flight No.': '86', 'Date andtime (UTC)': '4 June 202001:25[35]', 'Version,booster[a]': 'F9 B5 ♺ B1049.5', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 7 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]'} realniy ryad
# {'Flight No.': '86', 'Date andtime (UTC)': '4 June 202001:25[35]', 'Version,booster[a]': 'F9 B5 ♺ B1049.5', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 7 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO'} realniy ryad
# {'Flight No.': '86', 'Date andtime (UTC)': '4 June 202001:25[35]', 'Version,booster[a]': 'F9 B5 ♺ B1049.5', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 7 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX'} realniy ryad
# {'Flight No.': '86', 'Date andtime (UTC)': '4 June 202001:25[35]', 'Version,booster[a]': 'F9 B5 ♺ B1049.5', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 7 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '86', 'Date andtime (UTC)': '4 June 202001:25[35]', 'Version,booster[a]': 'F9 B5 ♺ B1049.5', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 7 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launchoutcome': 'Success', 'Boosterlanding': 'Success(drone ship)'} realniy ryad
# RESHAYUSHIY  Success(drone ship)
# {'Flight No.': '87'} realniy ryad
# {'Flight No.': '87', 'Date andtime (UTC)': '13 June 202009:21[37]'} realniy ryad
# {'Flight No.': '87', 'Date andtime (UTC)': '13 June 202009:21[37]', 'Version,booster[a]': 'F9 B5 ♺ B1059.3'} realniy ryad
# {'Flight No.': '87', 'Date andtime (UTC)': '13 June 202009:21[37]', 'Version,booster[a]': 'F9 B5 ♺ B1059.3', 'Launchsite': 'CCSFS,SLC-40'} realniy ryad
# {'Flight No.': '87', 'Date andtime (UTC)': '13 June 202009:21[37]', 'Version,booster[a]': 'F9 B5 ♺ B1059.3', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 8 v1.0 (58\xa0satellites),[38][39]SkySats-16, -17, -18'} realniy ryad
# {'Flight No.': '87', 'Date andtime (UTC)': '13 June 202009:21[37]', 'Version,booster[a]': 'F9 B5 ♺ B1059.3', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 8 v1.0 (58\xa0satellites),[38][39]SkySats-16, -17, -18', 'Payload mass': '15,410\xa0kg (33,970\xa0lb)[37]'} realniy ryad
# {'Flight No.': '87', 'Date andtime (UTC)': '13 June 202009:21[37]', 'Version,booster[a]': 'F9 B5 ♺ B1059.3', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 8 v1.0 (58\xa0satellites),[38][39]SkySats-16, -17, -18', 'Payload mass': '15,410\xa0kg (33,970\xa0lb)[37]', 'Orbit': 'LEO'} realniy ryad
# {'Flight No.': '87', 'Date andtime (UTC)': '13 June 202009:21[37]', 'Version,booster[a]': 'F9 B5 ♺ B1059.3', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 8 v1.0 (58\xa0satellites),[38][39]SkySats-16, -17, -18', 'Payload mass': '15,410\xa0kg (33,970\xa0lb)[37]', 'Orbit': 'LEO', 'Customer': 'SpaceXPlanet Labs'} realniy ryad
# {'Flight No.': '87', 'Date andtime (UTC)': '13 June 202009:21[37]', 'Version,booster[a]': 'F9 B5 ♺ B1059.3', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 8 v1.0 (58\xa0satellites),[38][39]SkySats-16, -17, -18', 'Payload mass': '15,410\xa0kg (33,970\xa0lb)[37]', 'Orbit': 'LEO', 'Customer': 'SpaceXPlanet Labs', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '87', 'Date andtime (UTC)': '13 June 202009:21[37]', 'Version,booster[a]': 'F9 B5 ♺ B1059.3', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 8 v1.0 (58\xa0satellites),[38][39]SkySats-16, -17, -18', 'Payload mass': '15,410\xa0kg (33,970\xa0lb)[37]', 'Orbit': 'LEO', 'Customer': 'SpaceXPlanet Labs', 'Launchoutcome': 'Success', 'Boosterlanding': 'Success(drone ship)'} realniy ryad
# RESHAYUSHIY  Success(drone ship)
# {'Flight No.': '88'} realniy ryad
# {'Flight No.': '88', 'Date andtime (UTC)': '30 June 202020:10:46[42]'} realniy ryad
# {'Flight No.': '88', 'Date andtime (UTC)': '30 June 202020:10:46[42]', 'Version,booster[a]': 'F9 B5 B1060.1'} realniy ryad
# {'Flight No.': '88', 'Date andtime (UTC)': '30 June 202020:10:46[42]', 'Version,booster[a]': 'F9 B5 B1060.1', 'Launchsite': 'CCSFS,SLC-40'} realniy ryad
# {'Flight No.': '88', 'Date andtime (UTC)': '30 June 202020:10:46[42]', 'Version,booster[a]': 'F9 B5 B1060.1', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'GPS III-03 (Matthew Henson)'} realniy ryad
# {'Flight No.': '88', 'Date andtime (UTC)': '30 June 202020:10:46[42]', 'Version,booster[a]': 'F9 B5 B1060.1', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'GPS III-03 (Matthew Henson)', 'Payload mass': '4,311\xa0kg (9,504\xa0lb)[43]'} realniy ryad
# {'Flight No.': '88', 'Date andtime (UTC)': '30 June 202020:10:46[42]', 'Version,booster[a]': 'F9 B5 B1060.1', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'GPS III-03 (Matthew Henson)', 'Payload mass': '4,311\xa0kg (9,504\xa0lb)[43]', 'Orbit': 'MEO'} realniy ryad
# {'Flight No.': '88', 'Date andtime (UTC)': '30 June 202020:10:46[42]', 'Version,booster[a]': 'F9 B5 B1060.1', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'GPS III-03 (Matthew Henson)', 'Payload mass': '4,311\xa0kg (9,504\xa0lb)[43]', 'Orbit': 'MEO', 'Customer': 'U.S. Space Force[43]'} realniy ryad
# {'Flight No.': '88', 'Date andtime (UTC)': '30 June 202020:10:46[42]', 'Version,booster[a]': 'F9 B5 B1060.1', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'GPS III-03 (Matthew Henson)', 'Payload mass': '4,311\xa0kg (9,504\xa0lb)[43]', 'Orbit': 'MEO', 'Customer': 'U.S. Space Force[43]', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '88', 'Date andtime (UTC)': '30 June 202020:10:46[42]', 'Version,booster[a]': 'F9 B5 B1060.1', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'GPS III-03 (Matthew Henson)', 'Payload mass': '4,311\xa0kg (9,504\xa0lb)[43]', 'Orbit': 'MEO', 'Customer': 'U.S. Space Force[43]', 'Launchoutcome': 'Success', 'Boosterlanding': 'Success(drone ship)'} realniy ryad
# RESHAYUSHIY  Success(drone ship)
# {'Flight No.': '89'} realniy ryad
# {'Flight No.': '89', 'Date andtime (UTC)': '20 July 202021:30[57]'} realniy ryad
# {'Flight No.': '89', 'Date andtime (UTC)': '20 July 202021:30[57]', 'Version,booster[a]': 'F9 B5 ♺ B1058.2[58]'} realniy ryad
# {'Flight No.': '89', 'Date andtime (UTC)': '20 July 202021:30[57]', 'Version,booster[a]': 'F9 B5 ♺ B1058.2[58]', 'Launchsite': 'CCSFS,SLC-40'} realniy ryad
# {'Flight No.': '89', 'Date andtime (UTC)': '20 July 202021:30[57]', 'Version,booster[a]': 'F9 B5 ♺ B1058.2[58]', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'ANASIS-II'} realniy ryad
# {'Flight No.': '89', 'Date andtime (UTC)': '20 July 202021:30[57]', 'Version,booster[a]': 'F9 B5 ♺ B1058.2[58]', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'ANASIS-II', 'Payload mass': '5,000–6,000\xa0kg (11,000–13,000\xa0lb)'} realniy ryad
# {'Flight No.': '89', 'Date andtime (UTC)': '20 July 202021:30[57]', 'Version,booster[a]': 'F9 B5 ♺ B1058.2[58]', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'ANASIS-II', 'Payload mass': '5,000–6,000\xa0kg (11,000–13,000\xa0lb)', 'Orbit': 'GTO'} realniy ryad
# {'Flight No.': '89', 'Date andtime (UTC)': '20 July 202021:30[57]', 'Version,booster[a]': 'F9 B5 ♺ B1058.2[58]', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'ANASIS-II', 'Payload mass': '5,000–6,000\xa0kg (11,000–13,000\xa0lb)', 'Orbit': 'GTO', 'Customer': 'Republic of Korea Army'} realniy ryad
# {'Flight No.': '89', 'Date andtime (UTC)': '20 July 202021:30[57]', 'Version,booster[a]': 'F9 B5 ♺ B1058.2[58]', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'ANASIS-II', 'Payload mass': '5,000–6,000\xa0kg (11,000–13,000\xa0lb)', 'Orbit': 'GTO', 'Customer': 'Republic of Korea Army', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '89', 'Date andtime (UTC)': '20 July 202021:30[57]', 'Version,booster[a]': 'F9 B5 ♺ B1058.2[58]', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'ANASIS-II', 'Payload mass': '5,000–6,000\xa0kg (11,000–13,000\xa0lb)', 'Orbit': 'GTO', 'Customer': 'Republic of Korea Army', 'Launchoutcome': 'Success', 'Boosterlanding': 'Success(drone ship)'} realniy ryad
# RESHAYUSHIY  Success(drone ship)
# {'Flight No.': '90'} realniy ryad
# {'Flight No.': '90', 'Date andtime (UTC)': '7 August 202005:12[63]'} realniy ryad
# {'Flight No.': '90', 'Date andtime (UTC)': '7 August 202005:12[63]', 'Version,booster[a]': 'F9 B5 ♺ B1051.5'} realniy ryad
# {'Flight No.': '90', 'Date andtime (UTC)': '7 August 202005:12[63]', 'Version,booster[a]': 'F9 B5 ♺ B1051.5', 'Launchsite': 'KSC,LC-39A'} realniy ryad
# {'Flight No.': '90', 'Date andtime (UTC)': '7 August 202005:12[63]', 'Version,booster[a]': 'F9 B5 ♺ B1051.5', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 9 v1.0 (57 Satellites),[38]SXRS-1 (BlackSky Global 7 and 8)'} realniy ryad
# {'Flight No.': '90', 'Date andtime (UTC)': '7 August 202005:12[63]', 'Version,booster[a]': 'F9 B5 ♺ B1051.5', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 9 v1.0 (57 Satellites),[38]SXRS-1 (BlackSky Global 7 and 8)', 'Payload mass': '14,932\xa0kg (32,919\xa0lb)'} realniy ryad
# {'Flight No.': '90', 'Date andtime (UTC)': '7 August 202005:12[63]', 'Version,booster[a]': 'F9 B5 ♺ B1051.5', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 9 v1.0 (57 Satellites),[38]SXRS-1 (BlackSky Global 7 and 8)', 'Payload mass': '14,932\xa0kg (32,919\xa0lb)', 'Orbit': 'LEO'} realniy ryad
# {'Flight No.': '90', 'Date andtime (UTC)': '7 August 202005:12[63]', 'Version,booster[a]': 'F9 B5 ♺ B1051.5', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 9 v1.0 (57 Satellites),[38]SXRS-1 (BlackSky Global 7 and 8)', 'Payload mass': '14,932\xa0kg (32,919\xa0lb)', 'Orbit': 'LEO', 'Customer': 'SpaceXSpaceflight Industries (BlackSky)'} realniy ryad
# {'Flight No.': '90', 'Date andtime (UTC)': '7 August 202005:12[63]', 'Version,booster[a]': 'F9 B5 ♺ B1051.5', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 9 v1.0 (57 Satellites),[38]SXRS-1 (BlackSky Global 7 and 8)', 'Payload mass': '14,932\xa0kg (32,919\xa0lb)', 'Orbit': 'LEO', 'Customer': 'SpaceXSpaceflight Industries (BlackSky)', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '90', 'Date andtime (UTC)': '7 August 202005:12[63]', 'Version,booster[a]': 'F9 B5 ♺ B1051.5', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 9 v1.0 (57 Satellites),[38]SXRS-1 (BlackSky Global 7 and 8)', 'Payload mass': '14,932\xa0kg (32,919\xa0lb)', 'Orbit': 'LEO', 'Customer': 'SpaceXSpaceflight Industries (BlackSky)', 'Launchoutcome': 'Success', 'Boosterlanding': 'Success(drone ship)'} realniy ryad
# RESHAYUSHIY  Success(drone ship)
# {'Flight No.': '91'} realniy ryad
# {'Flight No.': '91', 'Date andtime (UTC)': '18 August 202014:31[67]'} realniy ryad
# {'Flight No.': '91', 'Date andtime (UTC)': '18 August 202014:31[67]', 'Version,booster[a]': 'F9 B5 ♺ B1049.6[58]'} realniy ryad
# {'Flight No.': '91', 'Date andtime (UTC)': '18 August 202014:31[67]', 'Version,booster[a]': 'F9 B5 ♺ B1049.6[58]', 'Launchsite': 'CCSFS,SLC-40'} realniy ryad
# {'Flight No.': '91', 'Date andtime (UTC)': '18 August 202014:31[67]', 'Version,booster[a]': 'F9 B5 ♺ B1049.6[58]', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 10 v1.0 (58\xa0satellites)SkySat-19, -20, -21'} realniy ryad
# {'Flight No.': '91', 'Date andtime (UTC)': '18 August 202014:31[67]', 'Version,booster[a]': 'F9 B5 ♺ B1049.6[58]', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 10 v1.0 (58\xa0satellites)SkySat-19, -20, -21', 'Payload mass': '~15,440\xa0kg (34,040\xa0lb)'} realniy ryad
# {'Flight No.': '91', 'Date andtime (UTC)': '18 August 202014:31[67]', 'Version,booster[a]': 'F9 B5 ♺ B1049.6[58]', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 10 v1.0 (58\xa0satellites)SkySat-19, -20, -21', 'Payload mass': '~15,440\xa0kg (34,040\xa0lb)', 'Orbit': 'LEO'} realniy ryad
# {'Flight No.': '91', 'Date andtime (UTC)': '18 August 202014:31[67]', 'Version,booster[a]': 'F9 B5 ♺ B1049.6[58]', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 10 v1.0 (58\xa0satellites)SkySat-19, -20, -21', 'Payload mass': '~15,440\xa0kg (34,040\xa0lb)', 'Orbit': 'LEO', 'Customer': 'SpaceXPlanet Labs'} realniy ryad
# {'Flight No.': '91', 'Date andtime (UTC)': '18 August 202014:31[67]', 'Version,booster[a]': 'F9 B5 ♺ B1049.6[58]', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 10 v1.0 (58\xa0satellites)SkySat-19, -20, -21', 'Payload mass': '~15,440\xa0kg (34,040\xa0lb)', 'Orbit': 'LEO', 'Customer': 'SpaceXPlanet Labs', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '91', 'Date andtime (UTC)': '18 August 202014:31[67]', 'Version,booster[a]': 'F9 B5 ♺ B1049.6[58]', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 10 v1.0 (58\xa0satellites)SkySat-19, -20, -21', 'Payload mass': '~15,440\xa0kg (34,040\xa0lb)', 'Orbit': 'LEO', 'Customer': 'SpaceXPlanet Labs', 'Launchoutcome': 'Success', 'Boosterlanding': 'Success(drone ship)'} realniy ryad
# RESHAYUSHIY  Success(drone ship)
# {'Flight No.': '92'} realniy ryad
# {'Flight No.': '92', 'Date andtime (UTC)': '30 August 202023:18[69]'} realniy ryad
# {'Flight No.': '92', 'Date andtime (UTC)': '30 August 202023:18[69]', 'Version,booster[a]': 'F9 B5 ♺ B1059.4'} realniy ryad
# {'Flight No.': '92', 'Date andtime (UTC)': '30 August 202023:18[69]', 'Version,booster[a]': 'F9 B5 ♺ B1059.4', 'Launchsite': 'CCSFS,SLC-40'} realniy ryad
# {'Flight No.': '92', 'Date andtime (UTC)': '30 August 202023:18[69]', 'Version,booster[a]': 'F9 B5 ♺ B1059.4', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'SAOCOM 1B[70]GNOMES 1[70]Tyvak-0172[71]'} realniy ryad
# {'Flight No.': '92', 'Date andtime (UTC)': '30 August 202023:18[69]', 'Version,booster[a]': 'F9 B5 ♺ B1059.4', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'SAOCOM 1B[70]GNOMES 1[70]Tyvak-0172[71]', 'Payload mass': '3,130\xa0kg (6,900\xa0lb)[72]'} realniy ryad
# {'Flight No.': '92', 'Date andtime (UTC)': '30 August 202023:18[69]', 'Version,booster[a]': 'F9 B5 ♺ B1059.4', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'SAOCOM 1B[70]GNOMES 1[70]Tyvak-0172[71]', 'Payload mass': '3,130\xa0kg (6,900\xa0lb)[72]', 'Orbit': 'SSO'} realniy ryad
# {'Flight No.': '92', 'Date andtime (UTC)': '30 August 202023:18[69]', 'Version,booster[a]': 'F9 B5 ♺ B1059.4', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'SAOCOM 1B[70]GNOMES 1[70]Tyvak-0172[71]', 'Payload mass': '3,130\xa0kg (6,900\xa0lb)[72]', 'Orbit': 'SSO', 'Customer': 'CONAEPlanetIQTyvak'} realniy ryad
# {'Flight No.': '92', 'Date andtime (UTC)': '30 August 202023:18[69]', 'Version,booster[a]': 'F9 B5 ♺ B1059.4', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'SAOCOM 1B[70]GNOMES 1[70]Tyvak-0172[71]', 'Payload mass': '3,130\xa0kg (6,900\xa0lb)[72]', 'Orbit': 'SSO', 'Customer': 'CONAEPlanetIQTyvak', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '92', 'Date andtime (UTC)': '30 August 202023:18[69]', 'Version,booster[a]': 'F9 B5 ♺ B1059.4', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'SAOCOM 1B[70]GNOMES 1[70]Tyvak-0172[71]', 'Payload mass': '3,130\xa0kg (6,900\xa0lb)[72]', 'Orbit': 'SSO', 'Customer': 'CONAEPlanetIQTyvak', 'Launchoutcome': 'Success', 'Boosterlanding': 'Success(ground pad)'} realniy ryad
# RESHAYUSHIY  Success(ground pad)
# {'Flight No.': '93'} realniy ryad
# {'Flight No.': '93', 'Date andtime (UTC)': '3 September 202012:46:14[76]'} realniy ryad
# {'Flight No.': '93', 'Date andtime (UTC)': '3 September 202012:46:14[76]', 'Version,booster[a]': 'F9 B5 ♺ B1060.2[77]'} realniy ryad
# {'Flight No.': '93', 'Date andtime (UTC)': '3 September 202012:46:14[76]', 'Version,booster[a]': 'F9 B5 ♺ B1060.2[77]', 'Launchsite': 'KSC,LC-39A'} realniy ryad
# {'Flight No.': '93', 'Date andtime (UTC)': '3 September 202012:46:14[76]', 'Version,booster[a]': 'F9 B5 ♺ B1060.2[77]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 11 v1.0 (60\xa0satellites)'} realniy ryad
# {'Flight No.': '93', 'Date andtime (UTC)': '3 September 202012:46:14[76]', 'Version,booster[a]': 'F9 B5 ♺ B1060.2[77]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 11 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]'} realniy ryad
# {'Flight No.': '93', 'Date andtime (UTC)': '3 September 202012:46:14[76]', 'Version,booster[a]': 'F9 B5 ♺ B1060.2[77]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 11 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO'} realniy ryad
# {'Flight No.': '93', 'Date andtime (UTC)': '3 September 202012:46:14[76]', 'Version,booster[a]': 'F9 B5 ♺ B1060.2[77]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 11 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX'} realniy ryad
# {'Flight No.': '93', 'Date andtime (UTC)': '3 September 202012:46:14[76]', 'Version,booster[a]': 'F9 B5 ♺ B1060.2[77]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 11 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '93', 'Date andtime (UTC)': '3 September 202012:46:14[76]', 'Version,booster[a]': 'F9 B5 ♺ B1060.2[77]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 11 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launchoutcome': 'Success', 'Boosterlanding': 'Success(drone ship)'} realniy ryad
# RESHAYUSHIY  Success(drone ship)
# {'Flight No.': '94'} realniy ryad
# {'Flight No.': '94', 'Date andtime (UTC)': '6 October 202011:29:34[78]'} realniy ryad
# {'Flight No.': '94', 'Date andtime (UTC)': '6 October 202011:29:34[78]', 'Version,booster[a]': 'F9 B5 ♺ B1058.3[79]'} realniy ryad
# {'Flight No.': '94', 'Date andtime (UTC)': '6 October 202011:29:34[78]', 'Version,booster[a]': 'F9 B5 ♺ B1058.3[79]', 'Launchsite': 'KSC,LC-39A'} realniy ryad
# {'Flight No.': '94', 'Date andtime (UTC)': '6 October 202011:29:34[78]', 'Version,booster[a]': 'F9 B5 ♺ B1058.3[79]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 12 v1.0 (60\xa0satellites)'} realniy ryad
# {'Flight No.': '94', 'Date andtime (UTC)': '6 October 202011:29:34[78]', 'Version,booster[a]': 'F9 B5 ♺ B1058.3[79]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 12 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]'} realniy ryad
# {'Flight No.': '94', 'Date andtime (UTC)': '6 October 202011:29:34[78]', 'Version,booster[a]': 'F9 B5 ♺ B1058.3[79]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 12 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO'} realniy ryad
# {'Flight No.': '94', 'Date andtime (UTC)': '6 October 202011:29:34[78]', 'Version,booster[a]': 'F9 B5 ♺ B1058.3[79]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 12 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX'} realniy ryad
# {'Flight No.': '94', 'Date andtime (UTC)': '6 October 202011:29:34[78]', 'Version,booster[a]': 'F9 B5 ♺ B1058.3[79]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 12 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '94', 'Date andtime (UTC)': '6 October 202011:29:34[78]', 'Version,booster[a]': 'F9 B5 ♺ B1058.3[79]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 12 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launchoutcome': 'Success', 'Boosterlanding': 'Success(drone ship)'} realniy ryad
# RESHAYUSHIY  Success(drone ship)
# {'Flight No.': '95'} realniy ryad
# {'Flight No.': '95', 'Date andtime (UTC)': '18 October 202012:25:57[81]'} realniy ryad
# {'Flight No.': '95', 'Date andtime (UTC)': '18 October 202012:25:57[81]', 'Version,booster[a]': 'F9 B5 ♺ B1051.6[82]'} realniy ryad
# {'Flight No.': '95', 'Date andtime (UTC)': '18 October 202012:25:57[81]', 'Version,booster[a]': 'F9 B5 ♺ B1051.6[82]', 'Launchsite': 'KSC,LC-39A'} realniy ryad
# {'Flight No.': '95', 'Date andtime (UTC)': '18 October 202012:25:57[81]', 'Version,booster[a]': 'F9 B5 ♺ B1051.6[82]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 13 v1.0 (60\xa0satellites)'} realniy ryad
# {'Flight No.': '95', 'Date andtime (UTC)': '18 October 202012:25:57[81]', 'Version,booster[a]': 'F9 B5 ♺ B1051.6[82]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 13 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]'} realniy ryad
# {'Flight No.': '95', 'Date andtime (UTC)': '18 October 202012:25:57[81]', 'Version,booster[a]': 'F9 B5 ♺ B1051.6[82]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 13 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO'} realniy ryad
# {'Flight No.': '95', 'Date andtime (UTC)': '18 October 202012:25:57[81]', 'Version,booster[a]': 'F9 B5 ♺ B1051.6[82]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 13 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX'} realniy ryad
# {'Flight No.': '95', 'Date andtime (UTC)': '18 October 202012:25:57[81]', 'Version,booster[a]': 'F9 B5 ♺ B1051.6[82]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 13 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '95', 'Date andtime (UTC)': '18 October 202012:25:57[81]', 'Version,booster[a]': 'F9 B5 ♺ B1051.6[82]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Starlink 13 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)[4]', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launchoutcome': 'Success', 'Boosterlanding': 'Success(drone ship)'} realniy ryad
# RESHAYUSHIY  Success(drone ship)
# {'Flight No.': '96'} realniy ryad
# {'Flight No.': '96', 'Date andtime (UTC)': '24 October 202015:31:34[84]'} realniy ryad
# {'Flight No.': '96', 'Date andtime (UTC)': '24 October 202015:31:34[84]', 'Version,booster[a]': 'F9 B5 ♺ B1060.3'} realniy ryad
# {'Flight No.': '96', 'Date andtime (UTC)': '24 October 202015:31:34[84]', 'Version,booster[a]': 'F9 B5 ♺ B1060.3', 'Launchsite': 'CCSFS,SLC-40'} realniy ryad
# {'Flight No.': '96', 'Date andtime (UTC)': '24 October 202015:31:34[84]', 'Version,booster[a]': 'F9 B5 ♺ B1060.3', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 14 v1.0 (60\xa0satellites)'} realniy ryad
# {'Flight No.': '96', 'Date andtime (UTC)': '24 October 202015:31:34[84]', 'Version,booster[a]': 'F9 B5 ♺ B1060.3', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 14 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)'} realniy ryad
# {'Flight No.': '96', 'Date andtime (UTC)': '24 October 202015:31:34[84]', 'Version,booster[a]': 'F9 B5 ♺ B1060.3', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 14 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)', 'Orbit': 'LEO'} realniy ryad
# {'Flight No.': '96', 'Date andtime (UTC)': '24 October 202015:31:34[84]', 'Version,booster[a]': 'F9 B5 ♺ B1060.3', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 14 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)', 'Orbit': 'LEO', 'Customer': 'SpaceX'} realniy ryad
# {'Flight No.': '96', 'Date andtime (UTC)': '24 October 202015:31:34[84]', 'Version,booster[a]': 'F9 B5 ♺ B1060.3', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 14 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '96', 'Date andtime (UTC)': '24 October 202015:31:34[84]', 'Version,booster[a]': 'F9 B5 ♺ B1060.3', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'Starlink 14 v1.0 (60\xa0satellites)', 'Payload mass': '15,600\xa0kg (34,400\xa0lb)', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launchoutcome': 'Success', 'Boosterlanding': 'Success(drone ship)'} realniy ryad
# RESHAYUSHIY  Success(drone ship)
# {'Flight No.': '97'} realniy ryad
# {'Flight No.': '97', 'Date andtime (UTC)': '5 November 202023:24:23[86]'} realniy ryad
# {'Flight No.': '97', 'Date andtime (UTC)': '5 November 202023:24:23[86]', 'Version,booster[a]': 'F9 B5 B1062.1'} realniy ryad
# {'Flight No.': '97', 'Date andtime (UTC)': '5 November 202023:24:23[86]', 'Version,booster[a]': 'F9 B5 B1062.1', 'Launchsite': 'CCSFS,SLC-40'} realniy ryad
# {'Flight No.': '97', 'Date andtime (UTC)': '5 November 202023:24:23[86]', 'Version,booster[a]': 'F9 B5 B1062.1', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'GPS III-04 (Sacagawea)[54][87]'} realniy ryad
# {'Flight No.': '97', 'Date andtime (UTC)': '5 November 202023:24:23[86]', 'Version,booster[a]': 'F9 B5 B1062.1', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'GPS III-04 (Sacagawea)[54][87]', 'Payload mass': '4,311\xa0kg (9,504\xa0lb)'} realniy ryad
# {'Flight No.': '97', 'Date andtime (UTC)': '5 November 202023:24:23[86]', 'Version,booster[a]': 'F9 B5 B1062.1', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'GPS III-04 (Sacagawea)[54][87]', 'Payload mass': '4,311\xa0kg (9,504\xa0lb)', 'Orbit': 'MEO'} realniy ryad
# {'Flight No.': '97', 'Date andtime (UTC)': '5 November 202023:24:23[86]', 'Version,booster[a]': 'F9 B5 B1062.1', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'GPS III-04 (Sacagawea)[54][87]', 'Payload mass': '4,311\xa0kg (9,504\xa0lb)', 'Orbit': 'MEO', 'Customer': 'USSF'} realniy ryad
# {'Flight No.': '97', 'Date andtime (UTC)': '5 November 202023:24:23[86]', 'Version,booster[a]': 'F9 B5 B1062.1', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'GPS III-04 (Sacagawea)[54][87]', 'Payload mass': '4,311\xa0kg (9,504\xa0lb)', 'Orbit': 'MEO', 'Customer': 'USSF', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '97', 'Date andtime (UTC)': '5 November 202023:24:23[86]', 'Version,booster[a]': 'F9 B5 B1062.1', 'Launchsite': 'CCSFS,SLC-40', 'Payload[b]': 'GPS III-04 (Sacagawea)[54][87]', 'Payload mass': '4,311\xa0kg (9,504\xa0lb)', 'Orbit': 'MEO', 'Customer': 'USSF', 'Launchoutcome': 'Success', 'Boosterlanding': 'Success(drone ship)'} realniy ryad
# RESHAYUSHIY  Success(drone ship)
# {'Flight No.': '98'} realniy ryad
# {'Flight No.': '98', 'Date andtime (UTC)': '16 November 202000:27[95]'} realniy ryad
# {'Flight No.': '98', 'Date andtime (UTC)': '16 November 202000:27[95]', 'Version,booster[a]': 'F9 B5 B1061.1[96]'} realniy ryad
# {'Flight No.': '98', 'Date andtime (UTC)': '16 November 202000:27[95]', 'Version,booster[a]': 'F9 B5 B1061.1[96]', 'Launchsite': 'KSC,LC-39A'} realniy ryad
# {'Flight No.': '98', 'Date andtime (UTC)': '16 November 202000:27[95]', 'Version,booster[a]': 'F9 B5 B1061.1[96]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Crew-1(Crew Dragon C207.1 Resilience)'} realniy ryad
# {'Flight No.': '98', 'Date andtime (UTC)': '16 November 202000:27[95]', 'Version,booster[a]': 'F9 B5 B1061.1[96]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Crew-1(Crew Dragon C207.1 Resilience)', 'Payload mass': '~12,500\xa0kg (27,600\xa0lb)'} realniy ryad
# {'Flight No.': '98', 'Date andtime (UTC)': '16 November 202000:27[95]', 'Version,booster[a]': 'F9 B5 B1061.1[96]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Crew-1(Crew Dragon C207.1 Resilience)', 'Payload mass': '~12,500\xa0kg (27,600\xa0lb)', 'Orbit': 'LEO (ISS)'} realniy ryad
# {'Flight No.': '98', 'Date andtime (UTC)': '16 November 202000:27[95]', 'Version,booster[a]': 'F9 B5 B1061.1[96]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Crew-1(Crew Dragon C207.1 Resilience)', 'Payload mass': '~12,500\xa0kg (27,600\xa0lb)', 'Orbit': 'LEO (ISS)', 'Customer': 'NASA (CCP)[9]'} realniy ryad
# {'Flight No.': '98', 'Date andtime (UTC)': '16 November 202000:27[95]', 'Version,booster[a]': 'F9 B5 B1061.1[96]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Crew-1(Crew Dragon C207.1 Resilience)', 'Payload mass': '~12,500\xa0kg (27,600\xa0lb)', 'Orbit': 'LEO (ISS)', 'Customer': 'NASA (CCP)[9]', 'Launchoutcome': 'Success'} realniy ryad
# {'Flight No.': '98', 'Date andtime (UTC)': '16 November 202000:27[95]', 'Version,booster[a]': 'F9 B5 B1061.1[96]', 'Launchsite': 'KSC,LC-39A', 'Payload[b]': 'Crew-1(Crew Dragon C207.1 Resilience)', 'Payload mass': '~12,500\xa0kg (27,600\xa0lb)', 'Orbit': 'LEO (ISS)', 'Customer': 'NASA (CCP)[9]', 'Launchoutcome': 'Success', 'Boosterlanding': 'Success(drone ship)'} realniy ryad
# RESHAYUSHIY  Success(drone ship)
# {'Flight No.': '99'} realniy ryad
# {'Flight No.': '99', 'Date andtime (UTC)': '21 November 202017:17:08[101]'} realniy ryad
# {'Flight No.': '99', 'Date andtime (UTC)': '21 November 202017:17:08[101]', 'Version,booster[a]': 'F9 B5 B1063.1'} realniy ryad
# {'Flight No.': '99', 'Date andtime (UTC)': '21 November 202017:17:08[101]', 'Version,booster[a]': 'F9 B5 B1063.1', 'Launchsite': 'VSFB,SLC-4E'} realniy ryad
# {'Flight No.': '99', 'Date andtime (UTC)': '21 November 202017:17:08[101]', 'Version,booster[a]': 'F9 B5 B1063.1', 'Launchsite': 'VSFB,SLC-4E', 'Payload[b]': 'Sentinel-6 Michael Freilich (Jason-CS A)'} realniy ryad
# {'Flight No.': '99', 'Date andtime (UTC)': '21 November 202017:17:08[101]', 'Version,booster[a]': 'F9 B5 B1063.1', 'Launchsite': 'VSFB,SLC-4E', 'Payload[b]': 'Sentinel-6 Michael Freilich (Jason-CS A)', 'Payload mass': '1,192\xa0kg (2,628\xa0lb)'} realniy ryad
# {'Flight No.': '99', 'Date andtime (UTC)': '21 November 202017:17:08[101]', 'Version,booster[a]': 'F9 B5 B1063.1', 'Launchsite': 'VSFB,SLC-4E', 'Payload[b]': 'Sentinel-6 Michael Freilich (Jason-CS A)', 'Payload mass': '1,192\xa0kg (2,628\xa0lb)', 'Orbit': 'LEO'} realniy ryad
# {'Flight No.': '99', 'Date andtime (UTC)': '21 November 202017:17:08[101]', 'Version,booster[a]': 'F9 B5 B1063.1', 'Launchsite': 'VSFB,SLC-4E', 'Payload[b]': 'Sentinel-6 Michael Freilich (Jason-CS A)', 'Payload mass': '1,192\xa0kg (2,628\xa0lb)', 'Orbit': 'LEO', 'Customer': 'NASA / NOAA / ESA / EUMETSAT'} realniy ryad
# {'Flight No.': '99', 'Date andtime (UTC)': '21 November 202017:17:08[101]', 'Version,booster[a]': 'F9 B5 B1063.1', 'Launchsite': 'VSFB,SLC-4E', 'Payload[b]': 'Sentinel-6 Michael Freilich (Jason-CS A)', 'Payload mass': '1,192\xa0kg (2,628\xa0lb)', 'Orbit': 'LEO', 'Customer': 'NASA / NOAA / ESA / EUMETSAT', 'Launchoutcome': 'Success'} realniy ryad
# ...
# {'Flight No.': 'Eutelsat', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'No attempt', 'Launchsite': '187', 'Payload[b]': '26 November 202219:20[419]', 'Payload mass': 'F9 B5 B1076.1', 'Orbit': 'KSC,LC-39A', 'Customer': 'SpaceX CRS-26(Dragon C211.1)[420]'} realniy ryad
# {'Flight No.': 'Eutelsat', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'No attempt', 'Launchsite': '187', 'Payload[b]': '26 November 202219:20[419]', 'Payload mass': 'F9 B5 B1076.1', 'Orbit': 'KSC,LC-39A', 'Customer': 'SpaceX CRS-26(Dragon C211.1)[420]', 'Launchoutcome': '3,528\xa0kg (7,778\xa0lb)[421]'} realniy ryad
# {'Flight No.': 'Eutelsat', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'No attempt', 'Launchsite': '187', 'Payload[b]': '26 November 202219:20[419]', 'Payload mass': 'F9 B5 B1076.1', 'Orbit': 'KSC,LC-39A', 'Customer': 'SpaceX CRS-26(Dragon C211.1)[420]', 'Launchoutcome': '3,528\xa0kg (7,778\xa0lb)[421]', 'Boosterlanding': 'LEO (ISS)'} realniy ryad
# RESHAYUSHIY  LEO (ISS)
# {'Flight No.': 'NASA (CRS)'} realniy ryad
# {'Flight No.': 'NASA (CRS)', 'Date andtime (UTC)': 'Success'} realniy ryad
# {'Flight No.': 'NASA (CRS)', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)'} realniy ryad
# {'Flight No.': 'NASA (CRS)', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '188'} realniy ryad
# {'Flight No.': 'NASA (CRS)', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '188', 'Payload[b]': '8 December 202222:27[422]'} realniy ryad
# {'Flight No.': 'NASA (CRS)', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '188', 'Payload[b]': '8 December 202222:27[422]', 'Payload mass': 'F9 B5 ♺ B1069.4'} realniy ryad
# {'Flight No.': 'NASA (CRS)', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '188', 'Payload[b]': '8 December 202222:27[422]', 'Payload mass': 'F9 B5 ♺ B1069.4', 'Orbit': 'KSC,LC-39A'} realniy ryad
# {'Flight No.': 'NASA (CRS)', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '188', 'Payload[b]': '8 December 202222:27[422]', 'Payload mass': 'F9 B5 ♺ B1069.4', 'Orbit': 'KSC,LC-39A', 'Customer': 'OneWeb Flight #15 / SpaceX Flight 1 (40\xa0satellites)'} realniy ryad
# {'Flight No.': 'NASA (CRS)', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '188', 'Payload[b]': '8 December 202222:27[422]', 'Payload mass': 'F9 B5 ♺ B1069.4', 'Orbit': 'KSC,LC-39A', 'Customer': 'OneWeb Flight #15 / SpaceX Flight 1 (40\xa0satellites)', 'Launchoutcome': '6,000\xa0kg (13,000\xa0lb)'} realniy ryad
# {'Flight No.': 'NASA (CRS)', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '188', 'Payload[b]': '8 December 202222:27[422]', 'Payload mass': 'F9 B5 ♺ B1069.4', 'Orbit': 'KSC,LC-39A', 'Customer': 'OneWeb Flight #15 / SpaceX Flight 1 (40\xa0satellites)', 'Launchoutcome': '6,000\xa0kg (13,000\xa0lb)', 'Boosterlanding': 'Polar LEO'} realniy ryad
# RESHAYUSHIY  Polar LEO
# {'Flight No.': 'OneWeb'} realniy ryad
# {'Flight No.': 'OneWeb', 'Date andtime (UTC)': 'Success'} realniy ryad
# {'Flight No.': 'OneWeb', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)'} realniy ryad
# {'Flight No.': 'OneWeb', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '189'} realniy ryad
# {'Flight No.': 'OneWeb', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '189', 'Payload[b]': '11 December 202207:38[425]'} realniy ryad
# {'Flight No.': 'OneWeb', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '189', 'Payload[b]': '11 December 202207:38[425]', 'Payload mass': 'F9 B5 ♺  B1073.5'} realniy ryad
# {'Flight No.': 'OneWeb', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '189', 'Payload[b]': '11 December 202207:38[425]', 'Payload mass': 'F9 B5 ♺  B1073.5', 'Orbit': 'CCSFS,SLC-40'} realniy ryad
# {'Flight No.': 'OneWeb', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '189', 'Payload[b]': '11 December 202207:38[425]', 'Payload mass': 'F9 B5 ♺  B1073.5', 'Orbit': 'CCSFS,SLC-40', 'Customer': 'Hakuto-R Mission 1[426]Emirates Lunar MissionLunar Flashlight[427]'} realniy ryad
# {'Flight No.': 'OneWeb', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '189', 'Payload[b]': '11 December 202207:38[425]', 'Payload mass': 'F9 B5 ♺  B1073.5', 'Orbit': 'CCSFS,SLC-40', 'Customer': 'Hakuto-R Mission 1[426]Emirates Lunar MissionLunar Flashlight[427]', 'Launchoutcome': '~1,000\xa0kg (2,200\xa0lb)[428][429]'} realniy ryad
# {'Flight No.': 'OneWeb', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '189', 'Payload[b]': '11 December 202207:38[425]', 'Payload mass': 'F9 B5 ♺  B1073.5', 'Orbit': 'CCSFS,SLC-40', 'Customer': 'Hakuto-R Mission 1[426]Emirates Lunar MissionLunar Flashlight[427]', 'Launchoutcome': '~1,000\xa0kg (2,200\xa0lb)[428][429]', 'Boosterlanding': 'Ballistic lunar transfer (BLT)'} realniy ryad
# RESHAYUSHIY  Ballistic lunar transfer (BLT)
# {'Flight No.': 'ispace MBRSC  JAXA NASA'} realniy ryad
# {'Flight No.': 'ispace MBRSC  JAXA NASA', 'Date andtime (UTC)': 'Success'} realniy ryad
# {'Flight No.': 'ispace MBRSC  JAXA NASA', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)'} realniy ryad
# {'Flight No.': 'ispace MBRSC  JAXA NASA', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '190'} realniy ryad
# {'Flight No.': 'ispace MBRSC  JAXA NASA', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '190', 'Payload[b]': '16 December 202211:46[433]'} realniy ryad
# {'Flight No.': 'ispace MBRSC  JAXA NASA', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '190', 'Payload[b]': '16 December 202211:46[433]', 'Payload mass': 'F9 B5 ♺ B1071.6'} realniy ryad
# {'Flight No.': 'ispace MBRSC  JAXA NASA', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '190', 'Payload[b]': '16 December 202211:46[433]', 'Payload mass': 'F9 B5 ♺ B1071.6', 'Orbit': 'VSFB,SLC-4E'} realniy ryad
# {'Flight No.': 'ispace MBRSC  JAXA NASA', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '190', 'Payload[b]': '16 December 202211:46[433]', 'Payload mass': 'F9 B5 ♺ B1071.6', 'Orbit': 'VSFB,SLC-4E', 'Customer': 'Surface Water and Ocean Topography (SWOT)[434]'} realniy ryad
# {'Flight No.': 'ispace MBRSC  JAXA NASA', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '190', 'Payload[b]': '16 December 202211:46[433]', 'Payload mass': 'F9 B5 ♺ B1071.6', 'Orbit': 'VSFB,SLC-4E', 'Customer': 'Surface Water and Ocean Topography (SWOT)[434]', 'Launchoutcome': '~2,200\xa0kg (4,900\xa0lb)[435]'} realniy ryad
# {'Flight No.': 'ispace MBRSC  JAXA NASA', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '190', 'Payload[b]': '16 December 202211:46[433]', 'Payload mass': 'F9 B5 ♺ B1071.6', 'Orbit': 'VSFB,SLC-4E', 'Customer': 'Surface Water and Ocean Topography (SWOT)[434]', 'Launchoutcome': '~2,200\xa0kg (4,900\xa0lb)[435]', 'Boosterlanding': 'LEO'} realniy ryad
# RESHAYUSHIY  LEO
# {'Flight No.': 'NASA/CNES'} realniy ryad
# {'Flight No.': 'NASA/CNES', 'Date andtime (UTC)': 'Success'} realniy ryad
# {'Flight No.': 'NASA/CNES', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)'} realniy ryad
# {'Flight No.': 'NASA/CNES', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '191'} realniy ryad
# {'Flight No.': 'NASA/CNES', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '191', 'Payload[b]': '16 December 202222:48[437]'} realniy ryad
# {'Flight No.': 'NASA/CNES', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '191', 'Payload[b]': '16 December 202222:48[437]', 'Payload mass': 'F9 B5 ♺ B1067.8'} realniy ryad
# {'Flight No.': 'NASA/CNES', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '191', 'Payload[b]': '16 December 202222:48[437]', 'Payload mass': 'F9 B5 ♺ B1067.8', 'Orbit': 'CCSFS,SLC-40'} realniy ryad
# {'Flight No.': 'NASA/CNES', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '191', 'Payload[b]': '16 December 202222:48[437]', 'Payload mass': 'F9 B5 ♺ B1067.8', 'Orbit': 'CCSFS,SLC-40', 'Customer': 'O3b mPOWER 1\xa0&\xa02'} realniy ryad
# {'Flight No.': 'NASA/CNES', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '191', 'Payload[b]': '16 December 202222:48[437]', 'Payload mass': 'F9 B5 ♺ B1067.8', 'Orbit': 'CCSFS,SLC-40', 'Customer': 'O3b mPOWER 1\xa0&\xa02', 'Launchoutcome': '~4,100\xa0kg (9,000\xa0lb)'} realniy ryad
# {'Flight No.': 'NASA/CNES', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)', 'Launchsite': '191', 'Payload[b]': '16 December 202222:48[437]', 'Payload mass': 'F9 B5 ♺ B1067.8', 'Orbit': 'CCSFS,SLC-40', 'Customer': 'O3b mPOWER 1\xa0&\xa02', 'Launchoutcome': '~4,100\xa0kg (9,000\xa0lb)', 'Boosterlanding': 'MEO'} realniy ryad
# RESHAYUSHIY  MEO
# {'Flight No.': 'SES'} realniy ryad
# {'Flight No.': 'SES', 'Date andtime (UTC)': 'Success'} realniy ryad
# {'Flight No.': 'SES', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)'} realniy ryad
# {'Flight No.': 'SES', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '192'} realniy ryad
# {'Flight No.': 'SES', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '192', 'Payload[b]': '17 December 202221:32[437]'} realniy ryad
# {'Flight No.': 'SES', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '192', 'Payload[b]': '17 December 202221:32[437]', 'Payload mass': 'F9 B5 ♺ B1058.15'} realniy ryad
# {'Flight No.': 'SES', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '192', 'Payload[b]': '17 December 202221:32[437]', 'Payload mass': 'F9 B5 ♺ B1058.15', 'Orbit': 'KSC,LC-39A'} realniy ryad
# {'Flight No.': 'SES', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '192', 'Payload[b]': '17 December 202221:32[437]', 'Payload mass': 'F9 B5 ♺ B1058.15', 'Orbit': 'KSC,LC-39A', 'Customer': 'Starlink Group 4-37[440] (54\xa0satellites)'} realniy ryad
# {'Flight No.': 'SES', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '192', 'Payload[b]': '17 December 202221:32[437]', 'Payload mass': 'F9 B5 ♺ B1058.15', 'Orbit': 'KSC,LC-39A', 'Customer': 'Starlink Group 4-37[440] (54\xa0satellites)', 'Launchoutcome': '~16,700\xa0kg (36,800\xa0lb)'} realniy ryad
# {'Flight No.': 'SES', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '192', 'Payload[b]': '17 December 202221:32[437]', 'Payload mass': 'F9 B5 ♺ B1058.15', 'Orbit': 'KSC,LC-39A', 'Customer': 'Starlink Group 4-37[440] (54\xa0satellites)', 'Launchoutcome': '~16,700\xa0kg (36,800\xa0lb)', 'Boosterlanding': 'LEO'} realniy ryad
# RESHAYUSHIY  LEO
# {'Flight No.': 'SpaceX'} realniy ryad
# {'Flight No.': 'SpaceX', 'Date andtime (UTC)': 'Success'} realniy ryad
# {'Flight No.': 'SpaceX', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)'} realniy ryad
# {'Flight No.': 'SpaceX', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '193'} realniy ryad
# {'Flight No.': 'SpaceX', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '193', 'Payload[b]': '28 December 202209:34[441]'} realniy ryad
# {'Flight No.': 'SpaceX', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '193', 'Payload[b]': '28 December 202209:34[441]', 'Payload mass': 'F9 B5 ♺ B1062.11'} realniy ryad
# {'Flight No.': 'SpaceX', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '193', 'Payload[b]': '28 December 202209:34[441]', 'Payload mass': 'F9 B5 ♺ B1062.11', 'Orbit': 'CCSFS,SLC-40'} realniy ryad
# {'Flight No.': 'SpaceX', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '193', 'Payload[b]': '28 December 202209:34[441]', 'Payload mass': 'F9 B5 ♺ B1062.11', 'Orbit': 'CCSFS,SLC-40', 'Customer': 'Starlink Group 5-1 (54\xa0satellites)'} realniy ryad
# {'Flight No.': 'SpaceX', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '193', 'Payload[b]': '28 December 202209:34[441]', 'Payload mass': 'F9 B5 ♺ B1062.11', 'Orbit': 'CCSFS,SLC-40', 'Customer': 'Starlink Group 5-1 (54\xa0satellites)', 'Launchoutcome': '~16,700\xa0kg (36,800\xa0lb)'} realniy ryad
# {'Flight No.': 'SpaceX', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '193', 'Payload[b]': '28 December 202209:34[441]', 'Payload mass': 'F9 B5 ♺ B1062.11', 'Orbit': 'CCSFS,SLC-40', 'Customer': 'Starlink Group 5-1 (54\xa0satellites)', 'Launchoutcome': '~16,700\xa0kg (36,800\xa0lb)', 'Boosterlanding': 'LEO'} realniy ryad
# RESHAYUSHIY  LEO
# {'Flight No.': 'SpaceX'} realniy ryad
# {'Flight No.': 'SpaceX', 'Date andtime (UTC)': 'Success'} realniy ryad
# {'Flight No.': 'SpaceX', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)'} realniy ryad
# {'Flight No.': 'SpaceX', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '194'} realniy ryad
# {'Flight No.': 'SpaceX', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '194', 'Payload[b]': '30 December 202207:38[444]'} realniy ryad
# {'Flight No.': 'SpaceX', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '194', 'Payload[b]': '30 December 202207:38[444]', 'Payload mass': 'F9 B5 ♺ B1061.11'} realniy ryad
# {'Flight No.': 'SpaceX', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '194', 'Payload[b]': '30 December 202207:38[444]', 'Payload mass': 'F9 B5 ♺ B1061.11', 'Orbit': 'VSFB,SLC-4E'} realniy ryad
# {'Flight No.': 'SpaceX', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '194', 'Payload[b]': '30 December 202207:38[444]', 'Payload mass': 'F9 B5 ♺ B1061.11', 'Orbit': 'VSFB,SLC-4E', 'Customer': 'EROS-C3[445]'} realniy ryad
# {'Flight No.': 'SpaceX', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '194', 'Payload[b]': '30 December 202207:38[444]', 'Payload mass': 'F9 B5 ♺ B1061.11', 'Orbit': 'VSFB,SLC-4E', 'Customer': 'EROS-C3[445]', 'Launchoutcome': '~400\xa0kg (880\xa0lb)'} realniy ryad
# {'Flight No.': 'SpaceX', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(drone ship)', 'Launchsite': '194', 'Payload[b]': '30 December 202207:38[444]', 'Payload mass': 'F9 B5 ♺ B1061.11', 'Orbit': 'VSFB,SLC-4E', 'Customer': 'EROS-C3[445]', 'Launchoutcome': '~400\xa0kg (880\xa0lb)', 'Boosterlanding': 'Retrograde LEO'} realniy ryad
# RESHAYUSHIY  Retrograde LEO
# {'Flight No.': 'ImageSat International'} realniy ryad
# {'Flight No.': 'ImageSat International', 'Date andtime (UTC)': 'Success'} realniy ryad
# {'Flight No.': 'ImageSat International', 'Date andtime (UTC)': 'Success', 'Version,booster[a]': 'Success(ground pad)'} realniy ryad

# %% [markdown]
# Starting from the third table is our target table contains the actual launch records.

# %%
# Let's print the third table and check its content
first_launch_table = html_tables[2]
print(first_launch_table)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_339/1062754519.py in <module>
#       1 # Let's print the third table and check its content
# ----> 2 first_launch_table = html_tables[2]
#       3 print(first_launch_table)
#
# NameError: name 'html_tables' is not defined

# %% [markdown]
# You should able to see the columns names embedded in the table header elements `<th>` as follows:

# %% [markdown]
# ```
# <tr>
# <th scope="col">Flight No.
# </th>
# <th scope="col">Date and<br/>time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>Booster</a> <sup class="reference" id="cite_ref-booster_11-0"><a href="#cite_note-booster-11">[b]</a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_12-0"><a href="#cite_note-Dragon-12">[c]</a></sup>
# </th>
# <th scope="col">Payload mass
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th>
# <th scope="col">Launch<br/>outcome
# </th>
# <th scope="col"><a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">Booster<br/>landing</a>
# </th></tr>
# ```

# %% [markdown]
# Next, we just need to iterate through the `<th>` elements and apply the provided `extract_column_from_header()` to extract column name one by one

# %%
column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names

# %% [markdown]
# Check the extracted column names

# %%
print(column_names)
# Out:
# []

# %% [markdown]
# ## TASK 3: Create a data frame by parsing the launch HTML tables

# %% [markdown]
# We will create an empty dictionary with keys from the extracted column names in the previous task. Later, this dictionary will be converted into a Pandas dataframe

# %%
launch_dict= dict.fromkeys(column_names)

# Remove an irrelvant column
del launch_dict['Date and time ( )']

# Let's initial the launch_dict with each value to be an empty list
launch_dict['Flight No.'] = []
launch_dict['Launch site'] = []
launch_dict['Payload'] = []
launch_dict['Payload mass'] = []
launch_dict['Orbit'] = []
launch_dict['Customer'] = []
launch_dict['Launch outcome'] = []
# Added some new columns
launch_dict['Version Booster']=[]
launch_dict['Booster landing']=[]
launch_dict['Date']=[]
launch_dict['Time']=[]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_339/1229833708.py in <module>
#       2
#       3 # Remove an irrelvant column
# ----> 4 del launch_dict['Date and time ( )']
#       5
#       6 # Let's initial the launch_dict with each value to be an empty list
#
# KeyError: 'Date and time ( )'

# %% [markdown]
# Next, we just need to fill up the `launch_dict` with launch records extracted from table rows.

# %% [markdown]
# Usually, HTML tables in Wiki pages are likely to contain unexpected annotations and other types of noises, such as reference links `B0004.1[8]`, missing values `N/A [e]`, inconsistent formatting, etc.

# %% [markdown]
# To simplify the parsing process, we have provided an incomplete code snippet below to help you to fill up the `launch_dict`. Please complete the following code snippet with TODOs or you can choose to write your own logic to parse all launch tables:

# %%
extracted_row = 0
#Extract each table 
for table_number,table in enumerate(soup.find_all('table',"wikitable plainrowheaders collapsible")):
   # get table row 
    for rows in table.find_all("tr"):
        #check to see if first table heading is as number corresponding to launch a number 
        if rows.th:
            if rows.th.string:
                flight_number=rows.th.string.strip()
                flag=flight_number.isdigit()
        else:
            flag=False
        #get table element 
        row=rows.find_all('td')
        #if it is number save cells in a dictonary 
        if flag:
            extracted_row += 1
            # Flight Number value
            # TODO: Append the flight_number into launch_dict with key `Flight No.`
            #print(flight_number)
            datatimelist=date_time(row[0])
            
            # Date value
            # TODO: Append the date into launch_dict with key `Date`
            date = datatimelist[0].strip(',')
            #print(date)
            
            # Time value
            # TODO: Append the time into launch_dict with key `Time`
            time = datatimelist[1]
            #print(time)
              
            # Booster version
            # TODO: Append the bv into launch_dict with key `Version Booster`
            bv=booster_version(row[1])
            if not(bv):
                bv=row[1].a.string
            print(bv)
            
            # Launch Site
            # TODO: Append the bv into launch_dict with key `Launch Site`
            launch_site = row[2].a.string
            #print(launch_site)
            
            # Payload
            # TODO: Append the payload into launch_dict with key `Payload`
            payload = row[3].a.string
            #print(payload)
            
            # Payload Mass
            # TODO: Append the payload_mass into launch_dict with key `Payload mass`
            payload_mass = get_mass(row[4])
            #print(payload)
            
            # Orbit
            # TODO: Append the orbit into launch_dict with key `Orbit`
            orbit = row[5].a.string
            #print(orbit)
            
            # Customer
            # TODO: Append the customer into launch_dict with key `Customer`
            customer = row[6].a.string
            #print(customer)
            
            # Launch outcome
            # TODO: Append the launch_outcome into launch_dict with key `Launch outcome`
            launch_outcome = list(row[7].strings)[0]
            #print(launch_outcome)
            
            # Booster landing
            # TODO: Append the launch_outcome into launch_dict with key `Booster landing`
            booster_landing = landing_status(row[8])
            #print(booster_landing)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_339/354354048.py in <module>
#       1 extracted_row = 0
#       2 #Extract each table
# ----> 3 for table_number,table in enumerate(soup.find_all('table',"wikitable plainrowheaders collapsible")):
#       4    # get table row
#       5     for rows in table.find_all("tr"):
#
# NameError: name 'soup' is not defined

# %% [markdown]
# After you have fill in the parsed launch record values into `launch_dict`, you can create a dataframe from it.

# %%
df= pd.DataFrame({ key:pd.Series(value) for key, value in launch_dict.items() })

# %% [markdown]
# We can now export it to a <b>CSV</b> for the next section, but to make the answers consistent and in case you have difficulties finishing this lab.
#
# Following labs will be using a provided dataset to make each lab independent.

# %% [markdown]
# <code>df.to_csv('spacex_web_scraped.csv', index=False)</code>

# %% [markdown]
# ## Authors

# %% [markdown]
# <a href="https://www.linkedin.com/in/yan-luo-96288783/">Yan Luo</a>

# %% [markdown]
# <a href="https://www.linkedin.com/in/nayefaboutayoun/">Nayef Abou Tayoun</a>

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description      |
# | ----------------- | ------- | ---------- | ----------------------- |
# | 2021-06-09        | 1.0     | Yan Luo    | Tasks updates           |
# | 2020-11-10        | 1.0     | Nayef      | Created the initial version |

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
